# %%
import numpy as np
import torch
from torch import nn
import sys
import re
import struct,logging
import itertools
import torchvision
import pandas as pd
import json

# %%
## Kaldi IO
import numpy as np 
import sys
import re
import struct
import subprocess
from subprocess import Popen
def open_or_fd(file, mode='rb'):
    """ fd = open_or_fd(file)
     Open file, gzipped file, pipe, or forward the file-descriptor.
     Eventually seeks in the 'file' argument contains ':offset' suffix.
    """
    offset = None
    try:
        # strip 'ark:' prefix from r{x,w}filename (optional),
        if re.search('^(ark|scp)(,scp|,b|,t|,n?f|,n?p|,b?o|,n?s|,n?cs)*:', file):
            (prefix,file) = file.split(':',1)
        # separate offset from filename (optional),
        if re.search(':[0-9]+$', file):
            (file,offset) = file.rsplit(':',1)
        # input pipe?
        if file[-1] == '|':
            fd = popen(file[:-1], 'rb') # custom,
        # output pipe?
        elif file[0] == '|':
            fd = popen(file[1:], 'wb') # custom,
        # is it gzipped?
        elif file.split('.')[-1] == 'gz':
            fd = gzip.open(file, mode)
        # a normal file...
        else:
            fd = open(file, mode)
    except TypeError:
        # 'file' is opened file descriptor,
        fd = file
    # Eventually seek to offset,
    if offset != None: fd.seek(int(offset))
    return fd


def read_key(fd):
    """ [key] = read_key(fd)
     Read the utterance-key from the opened ark/stream descriptor 'fd'.
    """
    assert('b' in fd.mode), "Error: 'fd' was opened in text mode (in python3 use sys.stdin.buffer)"

    key = ''
    while 1:
        char = fd.read(1).decode("latin1")
        if char == '' : break
        if char == ' ' : break
        key += char
    key = key.strip()
    if key == '': return None # end of file,
    assert(re.match('^\S+$',key) != None) # check format (no whitespace!)
    return key


def read_vec_flt_ark(file_or_fd):
    """ generator(key,vec) = read_vec_flt_ark(file_or_fd)
     Create generator of (key,vector<float>) tuples, reading from an ark file/stream.
     file_or_fd : ark, gzipped ark, pipe or opened file descriptor.
     Read ark to a 'dictionary':
     d = { u:d for u,d in kaldi_io.read_vec_flt_ark(file) }
    """
    fd = open_or_fd(file_or_fd)
    try:
        key = read_key(fd)
        while key:
            ali = read_vec_flt(fd)
            yield key, ali
            key = read_key(fd)
    finally:
        if fd is not file_or_fd : fd.close()

def read_vec_flt(file_or_fd):
    """ [flt-vec] = read_vec_flt(file_or_fd)
     Read kaldi float vector, ascii or binary input,
    """
    fd = open_or_fd(file_or_fd)
    binary = fd.read(2).decode()
    if binary == '\0B': # binary flag
        ans = _read_vec_flt_binary(fd)
    else:    # ascii,
        arr = (binary + fd.readline().decode()).strip().split()
        try:
            arr.remove('['); arr.remove(']') # optionally
        except ValueError:
            pass
        ans = np.array(arr, dtype=float)
    if fd is not file_or_fd : fd.close() # cleanup
    return ans

def _read_vec_flt_binary(fd):
    header = fd.read(3).decode()
    if header == 'FV ' : sample_size = 4 # floats
    elif header == 'DV ' : sample_size = 8 # doubles
    else : raise UnknownVectorHeader("The header contained '%s'" % header)
    assert (sample_size > 0)
    # Dimension,
    assert (fd.read(1).decode() == '\4'); # int-size
    vec_size = np.frombuffer(fd.read(4), dtype='int32', count=1)[0] # vector dim
    if vec_size == 0:
        return np.array([], dtype='float32')
    # Read whole vector,
    buf = fd.read(vec_size * sample_size)
    if sample_size == 4 : ans = np.frombuffer(buf, dtype='float32')
    elif sample_size == 8 : ans = np.frombuffer(buf, dtype='float64')
    else : raise BadSampleSize
    return ans

# %%
def load_json(filename='data.json'):
    with open(filename, 'r') as outfile:
        data = json.load(outfile)
    return data


def write_to_json(data, filename='data.json'):
    with open(filename, 'w') as outfile:
        json.dump(data, outfile)

# %%
common_meta = pd.read_csv('vox2_meta.csv')
face_embed_data = load_json("../../../data/vggface2_voxceleb2_embeddings.json")

# List of face and voice IDs
# Contains the class names
dont_include = ['n003729 ' , 'n003754 ']

train_face_list, valid_face_list, test_face_list = [], [], []
train_voice_list, valid_voice_list, test_voice_list = [], [], []

for i in range(len(common_meta['Set '])):
    if common_meta['Set '].iloc[i] == "dev " and common_meta['VGGFace2 ID '].iloc[i] not in dont_include:
        train_face_list.append(common_meta['VGGFace2 ID '].iloc[i][:-1].strip())
        train_voice_list.append(common_meta['VoxCeleb2 ID '].iloc[i][:-1].strip())

    elif common_meta['Set '].iloc[i] == "test " and common_meta['VGGFace2 ID '].iloc[i][:-1] not in dont_include:
        test_face_list.append(common_meta['VGGFace2 ID '].iloc[i][:-1].strip())
        test_voice_list.append(common_meta['VoxCeleb2 ID '].iloc[i][:-1].strip())

train_xvec = load_json('../../../data/voice_nw_embeddings.json') #{ key.strip():vec.tolist() for key,vec in read_vec_flt_ark('../../../data/xvec_v2_train.ark')}
assert(len(list(train_xvec.keys()))==1092009)

trainval_spk2utt = {line.strip().split(' ')[0]:line.strip().split(' ')[1:] for line in open('../../../data/spk2utt_train','r').readlines()}
assert(len(list(trainval_spk2utt.keys()))==5994)

# %%
train_utt_ids = {}
train_face_embeds=[]
train_labels =[]
# valid_utt_ids ={}
# valid_face_embeds=[]
# valid_labels=[]
train_spk_list = train_voice_list
#print(len(train_voice_list),"SPK@UTT",len(list(trainval_spk2utt.keys())))
count=0
## Get voice utt iD's , labels to extract feats from train_xvec
for i in range(len(list(train_spk_list))):
    ## TRAIN
    utt_ids = trainval_spk2utt[train_spk_list[i]][:20]
    labels = [i] *20
    train_utt_ids[train_face_list[i]]=utt_ids
write_to_json(train_utt_ids,'spk_utt_ids.json')
#     ## VALID
#     utt_ids = trainval_spk2utt[train_spk_list[i]][20:25]
#     if len(utt_ids) < 5:
#         #print('INIT LEN ',len(utt_ids),utt_ids)
#         diff = -(len(utt_ids)-5)
#         #print('DIFF is',diff,"Factor is ",diff//len(utt_ids)+1)
#         utt_ids = utt_ids * (diff//len(utt_ids)+1)
#         #print('LATER LEN ',len(utt_ids),utt_ids)

#         if len(utt_ids)-5 !=0:
#             diff = -(len(utt_ids)-5)
#             #print('SECOND DIFF is',diff)
#             utt_ids = utt_ids + utt_ids[:diff]
#             #print('FINAL LEN IS',len(utt_ids))
#         assert(len(utt_ids)==5)
#         #print(train_spk_list[i],len(trainval_spk2utt[train_spk_list[i]]))
#     face_ids = face_embed_data[train_face_list[i]][20:25]
#     labels = [i] *25
#     valid_utt_ids.extend(utt_ids)
#     valid_face_embeds.extend(face_ids)
#     valid_labels.extend(labels)

# %%
train_utt_ids
# Out:
# {'n000012': ['id00012-21Uxsk56VDQ-00001',
#   'id00012-21Uxsk56VDQ-00002',
#   'id00012-21Uxsk56VDQ-00003',
#   'id00012-21Uxsk56VDQ-00004',
#   'id00012-21Uxsk56VDQ-00005',
#   'id00012-21Uxsk56VDQ-00006',
#   'id00012-21Uxsk56VDQ-00007',
#   'id00012-21Uxsk56VDQ-00008',
#   'id00012-21Uxsk56VDQ-00009',
#   'id00012-21Uxsk56VDQ-00010',
#   'id00012-21Uxsk56VDQ-00011',
#   'id00012-21Uxsk56VDQ-00012',
#   'id00012-21Uxsk56VDQ-00013',
#   'id00012-21Uxsk56VDQ-00014',
#   'id00012-21Uxsk56VDQ-00015',
#   'id00012-2DLq_Kkc1r8-00016',
#   'id00012-2DLq_Kkc1r8-00017',
#   'id00012-2DLq_Kkc1r8-00018',
#   'id00012-73OrGYvy4ng-00019',
#   'id00012-C_FAL9gv8bo-00020'],
#  'n000015': ['id00015-0fijmz4vTVU-00001',
#   'id00015-0fijmz4vTVU-00002',
#   'id00015-0iQWqFw6FOU-00003',
#   'id00015-0iQWqFw6FOU-00004',
#   'id00015-0iQWqFw6FOU-00005',
#   'id00015-0iQWqFw6FOU-00006',
#   'id00015-0iQWqFw6FOU-00007',
#   'id00015-0iQWqFw6FOU-00008',
#   'id00015-0iQWqFw6FOU-00009',
#   'id00015-0iQWqFw6FOU-00010',
#   'id00015-0iQWqFw6FOU-00011',
#   'id00015-0iQWqFw6FOU-00012',
#   'id00015-0iQWqFw6FOU-00013',
#   'id00015-0iQWqFw6FOU-00014',
#   'id00015-0iQWqFw6FOU-00015',
#   'id00015-0iQWqFw6FOU-00016',
#   'id00015-0iQWqFw6FOU-00017',
#   'id00015-0iQWqFw6FOU-00018',
#   'id00015-0iQWqFw6FOU-00019',
#   'id00015-0iQWqFw6FOU-00020'],
#  'n000016': ['id00016-0cLseJLGw2o-00001',
#   'id00016-0cLseJLGw2o-00002',
#   'id00016-29NOrEy8ZY0-00003',
#   'id00016-29NOrEy8ZY0-00004',
#   'id00016-29NOrEy8ZY0-00005',
#   'id00016-29NOrEy8ZY0-00006',
#   'id00016-29NOrEy8ZY0-00007',
#   'id00016-29NOrEy8ZY0-00008',
#   'id00016-29NOrEy8ZY0-00009',
#   'id00016-2niwwfAgJ7c-00010',
#   'id00016-3Ikj1W8iEyE-00011',
#   'id00016-3Ikj1W8iEyE-00012',
#   'id00016-3Ikj1W8iEyE-00013',
#   'id00016-3Ikj1W8iEyE-00014',
#   'id00016-3Ikj1W8iEyE-00015',
#   'id00016-3Ikj1W8iEyE-00016',
#   'id00016-3Ikj1W8iEyE-00017',
#   'id00016-5ml6HbZ9wm8-00018',
#   'id00016-5ml6HbZ9wm8-00019',
#   'id00016-7kCdyVoNj5M-00020'],
#  'n000018': ['id00018-31xSZXsKR9w-00001',
#   'id00018-31xSZXsKR9w-00002',
#   'id00021-6uNNej-JZ-c-00010',
#   'id00021-6uNNej-JZ-c-00011',
#   'id00021-6uNNej-JZ-c-00012',
#   'id00021-P6ALNEH-j4s-00013',
#   'id00021-SazFVU_X6tc-00014',
#   'id00021-UK1n15meqiI-00015',
#   'id00021-UK1n15meqiI-00016',
#   'id00021-bvzqVqPF2yU-00017',
#   'id00021-eDzvdgjRPKY-00018',
#   'id00021-eDzvdgjRPKY-00019',
#   'id00021-o3cihm7PGEE-00020'],
#  'n000022': ['id00022-0XgWV-KWRX8-00001',
#   'id00022-0XgWV-KWRX8-00002',
#   'id00022-0XgWV-KWRX8-00003',
#   'id00022-0XgWV-KWRX8-00004',
#   'id00022-0XgWV-KWRX8-00005',
#   'id00022-0XgWV-KWRX8-00006',
#   'id00022-0XgWV-KWRX8-00007',
#   'id00022-0XgWV-KWRX8-00008',
#   'id00022-0XgWV-KWRX8-00009',
#   'id00022-0XgWV-KWRX8-00010',
#   'id00022-0XgWV-KWRX8-00011',
#   'id00022-0XgWV-KWRX8-00012',
#   'id00022-0XgWV-KWRX8-00013',
#   'id00022-0XgWV-KWRX8-00014',
#   'id00022-0XgWV-KWRX8-00015',
#   'id00022-0XgWV-KWRX8-00016',
#   'id00022-0XgWV-KWRX8-00017',
#   'id00022-4_eooSFoVGg-00018',
#   'id00022-5HIYIprNMSo-00019',
#   'id00022-5HIYIprNMSo-00020'],
#  'n000024': ['id00024-3ysHAigPe68-00001',
#   'id00024-3ysHAigPe68-00002',
#   'id00024-3ysHAigPe68-00003',
#   'id00024-3ysHAigPe68-00004',
#   'id00024-3ysHAigPe68-00005',
#   'id00024-3ysHAigPe68-00006',
#   'id00024-3ysHAigPe68-00007',
#   'id00024-3ysHAigPe68-00008',
#   'id00024-3ysHAigPe68-00009',
#   'id00024-3ysHAigPe68-00010',
#   'id00024-3ysHAigPe68-00011',
#   'id00024-3ysHAigPe68-00012',
#   'id00024-3ysHAigPe68-00013',
#   'id00024-5OKm0fUMYS8-00014',
#   'id00024-5OKm0fUMYS8-00015',
#   'id00024-7tlWLfTXpXs-00016',
#   'id00024-7tlWLfTXpXs-00017',
#   'id00024-8wJl8BMFV3A-00018',
#   'id00024-8wJl8BMFV3A-00019',
#   'id00024-8wJl8BMFV3A-00020'],
#  'n000025': ['id00025-0zIu_8Ja4Ds-00001',
#   'id00025-0zIu_8Ja4Ds-00002',
#   'id00025-0zIu_8Ja4Ds-00003',
#   'id00025-0zIu_8Ja4Ds-00004',
#   'id00025-0zIu_8Ja4Ds-00005',
#   'id00025-0zIu_8Ja4Ds-00006',
#   'id00025-0zIu_8Ja4Ds-00007',
#   'id00025-0zIu_8Ja4Ds-00008',
#   'id00025-0zIu_8Ja4Ds-00009',
#   'id00025-2Zw01Ka2Dj0-00010',
#   'id00025-2Zw01Ka2Dj0-00011',
#   'id00025-O_ICgJ0s-_o-00012',
#   'id00025-O_ICgJ0s-_o-00013',
#   'id00025-O_ICgJ0s-_o-00014',
#   'id00025-O_ICgJ0s-_o-00015',
#   'id00025-O_ICgJ0s-_o-00016',
#   'id00025-O_ICgJ0s-_o-00017',
#   'id00025-O_ICgJ0s-_o-00018',
#   'id00025-O_ICgJ0s-_o-00019',
#   'id00025-O_ICgJ0s-_o-00020'],
#  'n000026': ['id00026-0pSKifneuS8-00001',
#   'id00026-5jqK2BegVjY-00002',
#   'id00026-5jqK2BegVjY-00003',
#   'id00026-5jqK2BegVjY-00004',
#   'id00026-A3jQ3ZgWqys-00005',
#   'id00026-A3jQ3ZgWqys-00006',
#   'id00026-A3jQ3ZgWqys-00007',
#   'id00026-CXU0C7OxPRg-00008',
#   'id00026-Gc0aWmBoDfo-00009',
#   'id00026-Gc0aWmBoDfo-00010',
#   'id00026-Gc0aWmBoDfo-00011',
#   'id00026-Gc0aWmBoDfo-00012',
#   'id00026-HlZH9s3mOGM-00013',
#   'id00026-KPiwotirhuQ-00014',
#   'id00026-KPiwotirhuQ-00015',
#   'id00026-KPiwotirhuQ-00016',
#   'id00026-KPiwotirhuQ-00017',
#   'id00026-KPiwotirhuQ-00018',
#   'id00026-KPiwotirhuQ-00019',
#   'id00026-KPiwotirhuQ-00020'],
#  'n000027': ['id00027-3TQ8zPkRTnY-00001',
#   'id00027-4H8NO-Ka_cs-00002',
#   'id00027-4H8NO-Ka_cs-00003',
#   'id00027-4H8NO-Ka_cs-00004',
#   'id00027-88xON3WjQ2o-00005',
#   'id00027-88xON3WjQ2o-00006',
#   'id00027-JMuqWztBPUk-00007',
#   'id00027-LpOrf1JrDiI-00008',
#   'id00027-S_RuflIuUdo-00009',
#   'id00027-Yvigeon7MQg-00010',
#   'id00027-ox44e9i9uzk-00011',
#   'id00027-p8vHa9N-pcY-00012',
#   'id00027-p8vHa9N-pcY-00013',
#   'id00027-p8vHa9N-pcY-00014',
#   'id00027-p8vHa9N-pcY-00015',
#   'id00027-p8vHa9N-pcY-00016',
#   'id00027-p8vHa9N-pcY-00017',
#   'id00027-p8vHa9N-pcY-00018',
#   'id00027-p8vHa9N-pcY-00019',
#   'id00027-p8vHa9N-pcY-00020'],
#  'n000028': ['id00028-3tUK4LFMMhU-00001',
#   'id00028-3tUK4LFMMhU-00002',
#   'id00028-3tUK4LFMMhU-00003',
#   'id00028-3tUK4LFMMhU-00004',
#   'id00028-3tUK4LFMMhU-00005',
#   'id00028-3tUK4LFMMhU-00006',
#   'id00028-3tUK4LFMMhU-00007',
#   'id00028-3tUK4LFMMhU-00008',
#   'id00028-3tUK4LFMMhU-00009',
#   'id00028-3tUK4LFMMhU-00010',
#   'id00028-4bQEh2OArA8-00011',
#   'id00028-4bQEh2OArA8-00012',
#   'id00028-4bQEh2OArA8-00013',
#   'id00028-4bQEh2OArA8-00014',
#   'id00028-4bQEh2OArA8-00015',
#   'id00028-9j_eEm1mA_M-00016',
#   'id00028-9j_eEm1mA_M-00017',
#   'id00028-9j_eEm1mA_M-00018',
#   'id00028-9j_eEm1mA_M-00019',
#   'id00028-9j_eEm1mA_M-00020'],
#  'n000029': ['id00029-96Z18I2UKAE-00001',
#   'id00046-9cMYmFeuvyg-00004',
#   'id00046-9cMYmFeuvyg-00005',
#   'id00046-9cMYmFeuvyg-00006',
#   'id00046-9cMYmFeuvyg-00007',
#   'id00046-9cMYmFeuvyg-00008',
#   'id00046-9h3XRcuVI0s-00009',
#   'id00046-9h3XRcuVI0s-00010',
#   'id00046-9h3XRcuVI0s-00011',
#   'id00046-9h3XRcuVI0s-00012',
#   'id00046-9h3XRcuVI0s-00013',
#   'id00046-9h3XRcuVI0s-00014',
#   'id00046-9h3XRcuVI0s-00015',
#   'id00046-9h3XRcuVI0s-00016',
#   'id00046-9h3XRcuVI0s-00017',
#   'id00046-9h3XRcuVI0s-00018',
#   'id00046-9h3XRcuVI0s-00019',
#   'id00046-AjgCL0dE_iM-00020'],
#  'n000047': ['id00047-4ifdMhcDw-w-00001',
#   'id00047-4ifdMhcDw-w-00002',
#   'id00047-54ics1LRwOU-00003',
#   'id00047-54ics1LRwOU-00004',
#   'id00047-54ics1LRwOU-00005',
#   'id00047-6kSwBpCcr2s-00006',
#   'id00047-6kSwBpCcr2s-00007',
#   'id00047-6kSwBpCcr2s-00008',
#   'id00047-6kSwBpCcr2s-00009',
#   'id00047-6kSwBpCcr2s-00010',
#   'id00047-6kSwBpCcr2s-00011',
#   'id00047-6kSwBpCcr2s-00012',
#   'id00047-6kSwBpCcr2s-00013',
#   'id00047-6kSwBpCcr2s-00014',
#   'id00047-6kSwBpCcr2s-00015',
#   'id00047-6kSwBpCcr2s-00016',
#   'id00047-6kSwBpCcr2s-00017',
#   'id00047-78BeU2oFO8A-00018',
#   'id00047-78BeU2oFO8A-00019',
#   'id00047-78BeU2oFO8A-00020'],
#  'n000049': ['id00049-1SEoZ5dpCck-00001',
#   'id00049-1SEoZ5dpCck-00002',
#   'id00049-1SEoZ5dpCck-00003',
#   'id00049-1SEoZ5dpCck-00004',
#   'id00049-1SEoZ5dpCck-00005',
#   'id00049-1SEoZ5dpCck-00006',
#   'id00049-1SEoZ5dpCck-00007',
#   'id00049-2B3dXXXHRGo-00008',
#   'id00049-2B3dXXXHRGo-00009',
#   'id00049-2B3dXXXHRGo-00010',
#   'id00049-2B3dXXXHRGo-00011',
#   'id00049-2B3dXXXHRGo-00012',
#   'id00049-40Zx-joApcI-00013',
#   'id00049-40Zx-joApcI-00014',
#   'id00049-40Zx-joApcI-00015',
#   'id00049-40Zx-joApcI-00016',
#   'id00049-5FIMgO0LCTs-00017',
#   'id00049-5FIMgO0LCTs-00018',
#   'id00049-5FIMgO0LCTs-00019',
#   'id00049-5FIMgO0LCTs-00020'],
#  'n000050': ['id00050-7YTxZmFceys-00001',
#   'id00050-7YTxZmFceys-00002',
#   'id00050-7YTxZmFceys-00003',
#   'id00050-7YTxZmFceys-00004',
#   'id00050-7YTxZmFceys-00005',
#   'id00050-7YTxZmFceys-00006',
#   'id00050-7YTxZmFceys-00007',
#   'id00050-9fYDqDfwYO0-00008',
#   'id00050-CDDayGoYzF0-00009',
#   'id00050-CDDayGoYzF0-00010',
#   'id00053-8PwwX3s_lRU-00019',
#   'id00053-DYMNdF03jEQ-00020'],
#  'n000055': ['id00055-0feK6iZUfbs-00001',
#   'id00055-1MLDiDWa6mA-00002',
#   'id00055-1MLDiDWa6mA-00003',
#   'id00055-6uSL8jAd5-8-00004',
#   'id00055-6uSL8jAd5-8-00005',
#   'id00055-6uSL8jAd5-8-00006',
#   'id00055-6uSL8jAd5-8-00007',
#   'id00055-6uSL8jAd5-8-00008',
#   'id00055-88RXKabkb9c-00009',
#   'id00055-88RXKabkb9c-00010',
#   'id00055-8yJKAN208XQ-00011',
#   'id00055-8yJKAN208XQ-00012',
#   'id00055-8yJKAN208XQ-00013',
#   'id00055-8yJKAN208XQ-00014',
#   'id00055-8yJKAN208XQ-00015',
#   'id00055-8yJKAN208XQ-00016',
#   'id00055-8yJKAN208XQ-00017',
#   'id00055-8yJKAN208XQ-00018',
#   'id00055-92-ocgib4a0-00019',
#   'id00055-92-ocgib4a0-00020'],
#  'n000056': ['id00056-0K9vwZHgen4-00001',
#   'id00056-0K9vwZHgen4-00002',
#   'id00056-0K9vwZHgen4-00003',
#   'id00056-0K9vwZHgen4-00004',
#   'id00056-0PdgLC7zkdE-00005',
#   'id00056-0PdgLC7zkdE-00006',
#   'id00056-0PdgLC7zkdE-00007',
#   'id00056-0PdgLC7zkdE-00008',
#   'id00056-0PdgLC7zkdE-00009',
#   'id00056-0PdgLC7zkdE-00010',
#   'id00056-0PdgLC7zkdE-00011',
#   'id00056-6OLQXduv5mY-00012',
#   'id00056-Cm2nZjYw7dk-00013',
#   'id00056-Cm2nZjYw7dk-00014',
#   'id00056-Cm2nZjYw7dk-00015',
#   'id00056-EEjaqWQ99uI-00016',
#   'id00056-EEjaqWQ99uI-00017',
#   'id00056-EEjaqWQ99uI-00018',
#   'id00056-EEjaqWQ99uI-00019',
#   'id00056-EEjaqWQ99uI-00020'],
#  'n000058': ['id00058-5vrNiPz7ZC4-00001',
#   'id00058-5vrNiPz7ZC4-00002',
#   'id00058-5vrNiPz7ZC4-00003',
#   'id00058-5vrNiPz7ZC4-00004',
#   'id00058-5vrNiPz7ZC4-00005',
#   'id00058-5vrNiPz7ZC4-00006',
#   'id00058-5vrNiPz7ZC4-00007',
#   'id00058-5vrNiPz7ZC4-00008',
#   'id00058-5vrNiPz7ZC4-00009',
#   'id00058-5vrNiPz7ZC4-00010',
#   'id00058-5vrNiPz7ZC4-00011',
#   'id00058-5vrNiPz7ZC4-00012',
#   'id00058-5vrNiPz7ZC4-00013',
#   'id00058-5vrNiPz7ZC4-00014',
#   'id00058-5vrNiPz7ZC4-00015',
#   'id00058-5vrNiPz7ZC4-00016',
#   'id00058-5vrNiPz7ZC4-00017',
#   'id00058-6PiUqI-q-1w-00018',
#   'id00058-6PiUqI-q-1w-00019',
#   'id00058-6PiUqI-q-1w-00020'],
#  'n000059': ['id00059-2Op-8sEG8jA-00001',
#   'id00059-2XyoZ87lf70-00002',
#   'id00059-2XyoZ87lf70-00003',
#   'id00059-2XyoZ87lf70-00004',
#   'id00059-2XyoZ87lf70-00005',
#   'id00059-78pAuQz8M54-00006',
#   'id00059-78pAuQz8M54-00007',
#   'id00059-7je4Dfq-bMM-00008',
#   'id00059-7je4Dfq-bMM-00009',
#   'id00059-90q1X2X9yPM-00010',
#   'id00059-90q1X2X9yPM-00011',
#   'id00059-90q1X2X9yPM-00012',
#   'id00059-90q1X2X9yPM-00013',
#   'id00059-90q1X2X9yPM-00014',
#   'id00059-90q1X2X9yPM-00015',
#   'id00059-90q1X2X9yPM-00016',
#   'id00059-90q1X2X9yPM-00017',
#   'id00059-90q1X2X9yPM-00018',
#   'id00059-90q1X2X9yPM-00019',
#   'id00059-90q1X2X9yPM-00020'],
#  'n000060': ['id00060-0AVdESwWFXA-00001',
#   'id00060-0AVdESwWFXA-00002',
#   'id00060-0AVdESwWFXA-00003',
#   'id00060-0AVdESwWFXA-00004',
#   'id00060-0AVdESwWFXA-00005',
#   'id00060-0AVdESwWFXA-00006',
#   'id00060-0AVdESwWFXA-00007',
#   'id00060-0AVdESwWFXA-00008',
#   'id00060-0AVdESwWFXA-00009',
#   'id00060-0AVdESwWFXA-00010',
#   'id00060-0AVdESwWFXA-00011',
#   'id00060-0AVdESwWFXA-00012',
#   'id00060-0AVdESwWFXA-00013',
#   'id00060-0AVdESwWFXA-00014',
#   'id00060-0AVdESwWFXA-00015',
#   'id00060-0AVdESwWFXA-00016',
#   'id00060-0AVdESwWFXA-00017',
#   'id00060-0AVdESwWFXA-00018',
#   'id00060-0AVdESwWFXA-00019',
#   'id00060-0AVdESwWFXA-00020'],
#  'n000062': ['id00062-15WcVRuAQK4-00001',
#   'id00062-15WcVRuAQK4-00002',
#   'id00062-15WcVRuAQK4-00003',
#   'id00062-15WcVRuAQK4-00004',
#   'id00062-15WcVRuAQK4-00005',
#   'id00062-15WcVRuAQK4-00006',
#   'id00062-15WcVRuAQK4-00007',
#   'id00062-15WcVRuAQK4-00008',
#   'id00062-15WcVRuAQK4-00009',
#   'id00062-15WcVRuAQK4-00010',
#   'id00062-15WcVRuAQK4-00011',
#   'id00062-267Cov0KMy4-00012',
#   'id00062-267Cov0KMy4-00013',
#   'id00062-267Cov0KMy4-00014',
#   'id00062-267Cov0KMy4-00015',
#   'id00062-267Cov0KMy4-00016',
#   'id00062-3S2v7GXWnb4-00017',
#   'id00062-3S2v7GXWnb4-00018',
#   'id00062-3S2v7GXWnb4-00019',
#   'id00062-3S2v7GXWnb4-00020'],
#  'n000063': ['id00063-8k_OUj7volg-00001',
#   'id00063-8k_OUj7volg-00002',
#   'id00063-DWRTT_Y3mco-00003',
#   'id00063-DWRTT_Y3mco-00004',
#   'id00063-DWRTT_Y3mco-00005',
#   'id00063-DWRTT_Y3mco-00006',
#   'id00063-JoRs10bxe14-00007',
#   'id00063-JoRs10bxe14-00008',
#   'id00063-JoRs10bxe14-00009',
#   'id00063-_dy_WkUvwZY-00010',
#   'id00063-_dy_WkUvwZY-00011',
#   'id00063-_dy_WkUvwZY-00012',
#   'id00067-GSpRMbA10Ko-00019',
#   'id00067-IRjhUu0LHdo-00020'],
#  'n000068': ['id00068-87KfuH7sucE-00001',
#   'id00068-87KfuH7sucE-00002',
#   'id00068-87KfuH7sucE-00003',
#   'id00068-A7uFnQw--bY-00004',
#   'id00068-ILyfV0Yi9RQ-00005',
#   'id00068-ILyfV0Yi9RQ-00006',
#   'id00068-ILyfV0Yi9RQ-00007',
#   'id00068-ILyfV0Yi9RQ-00008',
#   'id00068-UtWwxtWuuOk-00009',
#   'id00068-UtWwxtWuuOk-00010',
#   'id00068-cc5ow8s66fA-00011',
#   'id00068-cc5ow8s66fA-00012',
#   'id00068-cc5ow8s66fA-00013',
#   'id00068-cc5ow8s66fA-00014',
#   'id00068-cc5ow8s66fA-00015',
#   'id00068-cc5ow8s66fA-00016',
#   'id00068-hK7UCN-X6_I-00017',
#   'id00068-hK7UCN-X6_I-00018',
#   'id00068-hK7UCN-X6_I-00019',
#   'id00068-hK7UCN-X6_I-00020'],
#  'n000069': ['id00069-1a1t-lDsVBU-00001',
#   'id00069-37__jd7iC30-00002',
#   'id00069-37__jd7iC30-00003',
#   'id00069-37__jd7iC30-00004',
#   'id00069-37__jd7iC30-00005',
#   'id00069-37__jd7iC30-00006',
#   'id00069-37__jd7iC30-00007',
#   'id00069-37__jd7iC30-00008',
#   'id00069-6-2nNSWWcIQ-00009',
#   'id00069-6-2nNSWWcIQ-00010',
#   'id00069-6-2nNSWWcIQ-00011',
#   'id00069-6-2nNSWWcIQ-00012',
#   'id00069-6-2nNSWWcIQ-00013',
#   'id00069-6-2nNSWWcIQ-00014',
#   'id00069-7pQ-vaQuqig-00015',
#   'id00069-7pQ-vaQuqig-00016',
#   'id00069-7pQ-vaQuqig-00017',
#   'id00069-7pQ-vaQuqig-00018',
#   'id00069-7pQ-vaQuqig-00019',
#   'id00069-7pQ-vaQuqig-00020'],
#  'n000070': ['id00070-1Ibyvio76J0-00001',
#   'id00070-1Ibyvio76J0-00002',
#   'id00070-1Ibyvio76J0-00003',
#   'id00070-1Ibyvio76J0-00004',
#   'id00070-1Ibyvio76J0-00005',
#   'id00070-1Ibyvio76J0-00006',
#   'id00070-1Ibyvio76J0-00007',
#   'id00070-1Ibyvio76J0-00008',
#   'id00070-1Ibyvio76J0-00009',
#   'id00070-1Ibyvio76J0-00010',
#   'id00070-Azdri1kLJRo-00011',
#   'id00070-Azdri1kLJRo-00012',
#   'id00070-Azdri1kLJRo-00013',
#   'id00070-Azdri1kLJRo-00014',
#   'id00070-Azdri1kLJRo-00015',
#   'id00070-Azdri1kLJRo-00016',
#   'id00070-Azdri1kLJRo-00017',
#   'id00070-Azdri1kLJRo-00018',
#   'id00070-Azdri1kLJRo-00019',
#   'id00070-FZA5ux_1mhg-00020'],
#  'n000071': ['id00071-0JDAt0VQxT4-00001',
#   'id00071-0JDAt0VQxT4-00002',
#   'id00071-0JDAt0VQxT4-00003',
#   'id00071-0JDAt0VQxT4-00004',
#   'id00071-0JDAt0VQxT4-00005',
#   'id00075-TZsWcgUuFUk-00012',
#   'id00075-TZsWcgUuFUk-00013',
#   'id00075-TZsWcgUuFUk-00014',
#   'id00075-TZsWcgUuFUk-00015',
#   'id00075-TZsWcgUuFUk-00016',
#   'id00075-Yp7VpaRaqBY-00017',
#   'id00075-bYyfWT5CRac-00018',
#   'id00075-ngsjY9aa6MM-00019',
#   'id00075-ngsjY9aa6MM-00020'],
#  'n000076': ['id00076-3My5C6vnRwU-00001',
#   'id00076-3My5C6vnRwU-00002',
#   'id00076-3My5C6vnRwU-00003',
#   'id00076-3My5C6vnRwU-00004',
#   'id00076-3My5C6vnRwU-00005',
#   'id00076-3My5C6vnRwU-00006',
#   'id00076-3My5C6vnRwU-00007',
#   'id00076-62l0nUMiUYY-00008',
#   'id00076-62l0nUMiUYY-00009',
#   'id00076-62l0nUMiUYY-00010',
#   'id00076-7ObQlVTuu-U-00011',
#   'id00076-7ObQlVTuu-U-00012',
#   'id00076-7ObQlVTuu-U-00013',
#   'id00076-7ObQlVTuu-U-00014',
#   'id00076-7ObQlVTuu-U-00015',
#   'id00076-7ObQlVTuu-U-00016',
#   'id00076-8cpyqIwQLSU-00017',
#   'id00076-8cpyqIwQLSU-00018',
#   'id00076-8xX7083XIJk-00019',
#   'id00076-8xX7083XIJk-00020'],
#  'n000078': ['id00078-14Vea1ICdVY-00001',
#   'id00078-14Vea1ICdVY-00002',
#   'id00078-14Vea1ICdVY-00003',
#   'id00078-14Vea1ICdVY-00004',
#   'id00078-14Vea1ICdVY-00005',
#   'id00078-14Vea1ICdVY-00006',
#   'id00078-14Vea1ICdVY-00007',
#   'id00078-14Vea1ICdVY-00008',
#   'id00078-2ssqBOMICck-00009',
#   'id00078-2ssqBOMICck-00010',
#   'id00078-2ssqBOMICck-00011',
#   'id00078-2ssqBOMICck-00012',
#   'id00078-2ssqBOMICck-00013',
#   'id00078-2ssqBOMICck-00014',
#   'id00078-2ssqBOMICck-00015',
#   'id00078-2ssqBOMICck-00016',
#   'id00078-2ssqBOMICck-00017',
#   'id00078-2ssqBOMICck-00018',
#   'id00078-2ssqBOMICck-00019',
#   'id00078-2ssqBOMICck-00020'],
#  'n000079': ['id00079-6XlRpQWhRAs-00001',
#   'id00079-9ozO57RchWQ-00002',
#   'id00079-9ozO57RchWQ-00003',
#   'id00079-CJKvC8PlorY-00004',
#   'id00079-HajpkbXhX4s-00005',
#   'id00079-HajpkbXhX4s-00006',
#   'id00079-I5T4c01WT6Q-00007',
#   'id00079-I5T4c01WT6Q-00008',
#   'id00079-I5T4c01WT6Q-00009',
#   'id00079-I5T4c01WT6Q-00010',
#   'id00079-I5T4c01WT6Q-00011',
#   'id00079-I5T4c01WT6Q-00012',
#   'id00079-I5T4c01WT6Q-00013',
#   'id00079-QcOdTF7XWmM-00014',
#   'id00079-QcOdTF7XWmM-00015',
#   'id00079-QcOdTF7XWmM-00016',
#   'id00079-QcOdTF7XWmM-00017',
#   'id00079-Tys61Fdc1jY-00018',
#   'id00079-VblA_VWuFWo-00019',
#   'id00084-2ss1r-wlF1o-00006',
#   'id00084-2ss1r-wlF1o-00007',
#   'id00084-2ss1r-wlF1o-00008',
#   'id00084-2ss1r-wlF1o-00009',
#   'id00084-2ss1r-wlF1o-00010',
#   'id00084-2ss1r-wlF1o-00011',
#   'id00084-2ss1r-wlF1o-00012',
#   'id00084-2ss1r-wlF1o-00013',
#   'id00084-2ss1r-wlF1o-00014',
#   'id00084-2ss1r-wlF1o-00015',
#   'id00084-2ss1r-wlF1o-00016',
#   'id00084-2ss1r-wlF1o-00017',
#   'id00084-2unAw9ONcqs-00018',
#   'id00084-2unAw9ONcqs-00019',
#   'id00084-2unAw9ONcqs-00020'],
#  'n000085': ['id00085-6HKTvYCzUNI-00001',
#   'id00085-8J-K_XgeT_g-00002',
#   'id00085-FUPcTOHJUTc-00003',
#   'id00085-K_bk7SwEri8-00004',
#   'id00085-K_bk7SwEri8-00005',
#   'id00085-K_bk7SwEri8-00006',
#   'id00085-K_bk7SwEri8-00007',
#   'id00085-K_bk7SwEri8-00008',
#   'id00085-QNYdqJbADWk-00009',
#   'id00085-WFuatG6do5I-00010',
#   'id00085-WFuatG6do5I-00011',
#   'id00085-WFuatG6do5I-00012',
#   'id00085-WFuatG6do5I-00013',
#   'id00085-WFuatG6do5I-00014',
#   'id00085-WFuatG6do5I-00015',
#   'id00085-WFuatG6do5I-00016',
#   'id00085-Wj5CGRDqaA8-00017',
#   'id00085-Wj5CGRDqaA8-00018',
#   'id00085-ZI5UquDM-sk-00019',
#   'id00085-a_y2X1LsClA-00020'],
#  'n000086': ['id00086-0ipUPOwjrdA-00001',
#   'id00086-0kpTs9OTAq8-00002',
#   'id00086-0kpTs9OTAq8-00003',
#   'id00086-0kpTs9OTAq8-00004',
#   'id00086-0kpTs9OTAq8-00005',
#   'id00086-0kpTs9OTAq8-00006',
#   'id00086-3iKlG6L0t78-00007',
#   'id00086-3iKlG6L0t78-00008',
#   'id00086-3iKlG6L0t78-00009',
#   'id00086-4Ubmlpsk9Us-00010',
#   'id00086-4Ubmlpsk9Us-00011',
#   'id00086-4Ubmlpsk9Us-00012',
#   'id00086-4Ubmlpsk9Us-00013',
#   'id00086-4Ubmlpsk9Us-00014',
#   'id00086-4Ubmlpsk9Us-00015',
#   'id00086-4Ubmlpsk9Us-00016',
#   'id00086-4Ubmlpsk9Us-00017',
#   'id00086-4Ubmlpsk9Us-00018',
#   'id00086-4Ubmlpsk9Us-00019',
#   'id00086-4Ubmlpsk9Us-00020'],
#  'n000087': ['id00087-0ZbOp9FgZf8-00001',
#   'id00087-0ZbOp9FgZf8-00002',
#   'id00087-0ZbOp9FgZf8-00003',
#   'id00087-1bQKeb1K-L4-00004',
#   'id00087-1bQKeb1K-L4-00005',
#   'id00087-1bQKeb1K-L4-00006',
#   'id00087-8iDF8kAT0rM-00007',
#   'id00087-DOI8LlYFYys-00008',
#   'id00087-DOI8LlYFYys-00009',
#   'id00087-DOI8LlYFYys-00010',
#   'id00087-KcnrMx0B2J0-00011',
#   'id00087-KcnrMx0B2J0-00012',
#   'id00087-KcnrMx0B2J0-00013',
#   'id00087-KcnrMx0B2J0-00014',
#   'id00087-KcnrMx0B2J0-00015',
#   'id00087-KcnrMx0B2J0-00016',
#   'id00087-KcnrMx0B2J0-00017',
#   'id00087-Mr7p7lDP1LI-00018',
#   'id00087-Mr7p7lDP1LI-00019',
#   'id00087-Mr7p7lDP1LI-00020'],
#  'n000088': ['id00088-0ttDqH6UsQA-00001',
#   'id00088-2q2FYs4q2Ds-00002',
#   'id00088-2q2FYs4q2Ds-00003',
#   'id00088-6WIDWxr8vuU-00004',
#   'id00088-6WIDWxr8vuU-00005',
#   'id00088-7SqNGxwsifk-00006',
#   'id00088-7SqNGxwsifk-00007',
#   'id00088-7W6ysZIGtm4-00008',
#   'id00088-8cX2LFuCOnA-00009',
#   'id00088-DlzwyXu3e7o-00010',
#   'id00088-Ewx8qdPyWM4-00011',
#   'id00088-Ewx8qdPyWM4-00012',
#   'id00088-Ewx8qdPyWM4-00013',
#   'id00088-Ewx8qdPyWM4-00014',
#   'id00088-HFUlB6h24_I-00015',
#   'id00088-HFUlB6h24_I-00016',
#   'id00088-HFUlB6h24_I-00017',
#   'id00088-I28CzoLJLvg-00018',
#   'id00088-I28CzoLJLvg-00019',
#   'id00088-I28CzoLJLvg-00020'],
#  'n000089': ['id00089-1Sfbg1Onsyg-00001',
#   'id00089-1Sfbg1Onsyg-00002',
#   'id00089-1Sfbg1Onsyg-00003',
#   'id00089-1Sfbg1Onsyg-00004',
#   'id00089-1Sfbg1Onsyg-00005',
#   'id00089-1Sfbg1Onsyg-00006',
#   'id00089-1Sfbg1Onsyg-00007',
#   'id00089-1Sfbg1Onsyg-00008',
#   'id00089-1Sfbg1Onsyg-00009',
#   'id00089-1Sfbg1Onsyg-00010',
#   'id00089-1Sfbg1Onsyg-00011',
#   'id00089-1Sfbg1Onsyg-00012',
#   'id00089-4RuQj2IcP0I-00013',
#   'id00089-4RuQj2IcP0I-00014',
#   'id00089-4RuQj2IcP0I-00015',
#   'id00089-4RuQj2IcP0I-00016',
#   'id00089-4RuQj2IcP0I-00017',
#   'id00089-4RuQj2IcP0I-00018',
#   'id00089-4RuQj2IcP0I-00019',
#   'id00089-E3wvo9fwLpQ-00020'],
#  'n000090': ['id00090-11p0FIRENPI-00001',
#   'id00090-11p0FIRENPI-00002',
#   'id00090-11p0FIRENPI-00003',
#   'id00090-11p0FIRENPI-00004',
#   'id00090-11p0FIRENPI-00005',
#   'id00090-2u9qhS0DONU-00006',
#   'id00090-3hdHm8PO0Gc-00007',
#   'id00090-3hdHm8PO0Gc-00008',
#   'id00090-3hdHm8PO0Gc-00009',
#   'id00090-3hdHm8PO0Gc-00010',
#   'id00090-3hdHm8PO0Gc-00011',
#   'id00090-5bTiGVFa_HQ-00012',
#   'id00090-5bTiGVFa_HQ-00013',
#   'id00090-5bTiGVFa_HQ-00014',
#   'id00090-JidN8ClxurY-00015',
#   'id00090-JidN8ClxurY-00016',
#   'id00090-JidN8ClxurY-00017',
#   'id00090-JidN8ClxurY-00018',
#   'id00090-JidN8ClxurY-00019',
#   'id00090-JidN8ClxurY-00020'],
#  'n000091': ['id00091-9g8sS28nY9I-00001',
#   'id00091-FraHQCk7jOQ-00002',
#   'id00091-FraHQCk7jOQ-00003',
#   'id00091-FraHQCk7jOQ-00004',
#   'id00091-TKMoaawdP3c-00005',
#   'id00091-TKMoaawdP3c-00006',
#   'id00091-TKMoaawdP3c-00007',
#   'id00091-TKMoaawdP3c-00008',
#   'id00091-TKMoaawdP3c-00009',
#   'id00091-TKMoaawdP3c-00010',
#   'id00091-TKMoaawdP3c-00011',
#   'id00091-TKMoaawdP3c-00012',
#   'id00091-TKMoaawdP3c-00013',
#   'id00091-TKMoaawdP3c-00014',
#   'id00091-TKMoaawdP3c-00015',
#   'id00091-TKMoaawdP3c-00016',
#   'id00091-TKMoaawdP3c-00017',
#   'id00091-TKMoaawdP3c-00018',
#   'id00091-TKMoaawdP3c-00019',
#   'id00091-TKMoaawdP3c-00020'],
#  'n000092': ['id00092-6ksfuzd95Ug-00001',
#   'id00092-6ksfuzd95Ug-00002',
#   'id00092-9ntyrFwtfro-00003',
#   'id00092-CCUJzs4DNrs-00004',
#   'id00092-CCUJzs4DNrs-00005',
#   'id00092-HR7suhdYTqg-00006',
#   'id00092-HR7suhdYTqg-00007',
#   'id00092-HR7suhdYTqg-00008',
#   'id00092-HR7suhdYTqg-00009',
#   'id00092-HR7suhdYTqg-00010',
#   'id00092-PyxoYue4Tlw-00011',
#   'id00092-PyxoYue4Tlw-00012',
#   'id00092-PyxoYue4Tlw-00013',
#   'id00092-PyxoYue4Tlw-00014',
#   'id00092-PyxoYue4Tlw-00015',
#   'id00092-PyxoYue4Tlw-00016',
#   'id00092-PyxoYue4Tlw-00017',
#   'id00092-UORk6rtoT8c-00018',
#   'id00092-UORk6rtoT8c-00019',
#   'id00092-YPSuwQPZdn4-00020'],
#  'n000096': ['id00096-0dfvnM6qwNI-00001',
#   'id00096-4d915Daeggk-00002',
#   'id00096-4d915Daeggk-00003',
#   'id00096-5_zo1GPg2e8-00004',
#   'id00096-6LBunBrBt5c-00005',
#   'id00096-6LBunBrBt5c-00006',
#   'id00096-6LBunBrBt5c-00007',
#   'id00096-6LBunBrBt5c-00008',
#   'id00096-7d4EAUBquj4-00009',
#   'id00096-BUwCMZ1hAB8-00010',
#   'id00096-BUwCMZ1hAB8-00011',
#   'id00096-BUwCMZ1hAB8-00012',
#   'id00096-BUwCMZ1hAB8-00013',
#   'id00096-BUwCMZ1hAB8-00014',
#   'id00096-BUwCMZ1hAB8-00015',
#   'id00096-BUwCMZ1hAB8-00016',
#   'id00096-BUwCMZ1hAB8-00017',
#   'id00096-FWxpxZKojfI-00018',
#   'id00096-FWxpxZKojfI-00019',
#   'id00096-FWxpxZKojfI-00020'],
#  'n000097': ['id00097-1szurY95ujY-00001',
#   'id00097-1szurY95ujY-00002',
#   'id00097-1szurY95ujY-00003',
#   'id00097-1szurY95ujY-00004',
#   'id00097-1szurY95ujY-00005',
#   'id00097-1szurY95ujY-00006',
#   'id00097-1szurY95ujY-00007',
#   'id00097-1szurY95ujY-00008',
#   'id00097-20Nogxs2EGQ-00009',
#   'id00097-20Nogxs2EGQ-00010',
#   'id00097-20Nogxs2EGQ-00011',
#   'id00097-20Nogxs2EGQ-00012',
#   'id00097-3RpBpquXG0A-00013',
#   'id00097-3RpBpquXG0A-00014',
#   'id00097-3RpBpquXG0A-00015',
#   'id00097-3RpBpquXG0A-00016',
#   'id00097-3RpBpquXG0A-00017',
#   'id00097-97jDzSGdjSM-00018',
#   'id00097-9U_JJJ1TY9k-00019',
#   'id00097-9U_JJJ1TY9k-00020'],
#  'n000098': ['id00098-B33RKVmA9xs-00001',
#   'id00098-M7J2k9MeefM-00002',
#   'id00098-R1uAeUOAKHI-00003',
#   'id00098-Rs_fnQ0tnqQ-00004',
#   'id00098-Vi1PCGfT93E-00005',
#   'id00098-Vi1PCGfT93E-00006',
#   'id00098-Vi1PCGfT93E-00007',
#   'id00098-Vi1PCGfT93E-00008',
#   'id00098-Vi1PCGfT93E-00009',
#   'id00098-Vi1PCGfT93E-00010',
#   'id00098-j26yyXKQFG4-00011',
#   'id00098-j26yyXKQFG4-00012',
#   'id00098-j26yyXKQFG4-00013',
#   'id00098-j26yyXKQFG4-00014',
#   'id00098-j26yyXKQFG4-00015',
#   'id00098-j26yyXKQFG4-00016',
#   'id00098-j26yyXKQFG4-00017',
#   'id00098-j26yyXKQFG4-00018',
#   'id00098-j26yyXKQFG4-00019',
#   'id00098-j26yyXKQFG4-00020'],
#  'n000099': ['id00099-0OuaE0wmS8I-00001',
#   'id00099-9pUtnB0zXzI-00002',
#   'id00099-B2aS-9wcdiM-00003',
#   'id00099-DBmU-njS1xE-00004',
#   'id00099-DBmU-njS1xE-00005',
#   'id00099-DBmU-njS1xE-00006',
#   'id00099-DBmU-njS1xE-00007',
#   'id00099-DBmU-njS1xE-00008',
#   'id00099-DBmU-njS1xE-00009',
#   'id00099-DBmU-njS1xE-00010',
#   'id00099-DBmU-njS1xE-00011',
#   'id00099-DBmU-njS1xE-00012',
#   'id00099-DBmU-njS1xE-00013',
#   'id00099-DBmU-njS1xE-00014',
#   'id00099-DBmU-njS1xE-00015',
#   'id00099-DBmU-njS1xE-00016',
#   'id00099-GyVXa78mKto-00017',
#   'id00099-Kp2kA1RPla4-00018',
#   'id00099-LhPcBhlBk3s-00019',
#   'id00099-LhPcBhlBk3s-00020'],
#  'n000100': ['id00100-0-qKujfhqRI-00001',
#   'id00100-0azO2YG6Bq0-00002',
#   'id00100-0azO2YG6Bq0-00003',
#   'id00100-0azO2YG6Bq0-00004',
#   'id00100-0azO2YG6Bq0-00005',
#   'id00100-0azO2YG6Bq0-00006',
#   'id00100-0azO2YG6Bq0-00007',
#   'id00100-0azO2YG6Bq0-00008',
#   'id00100-Bzo6TSbDxTw-00009',
#   'id00100-Bzo6TSbDxTw-00010',
#   'id00100-Bzo6TSbDxTw-00011',
#   'id00105-K-_gOSEPihU-00019',
#   'id00105-K-_gOSEPihU-00020'],
#  'n000109': ['id00109-7tWkRG6O3JQ-00001',
#   'id00109-7tWkRG6O3JQ-00002',
#   'id00109-7tWkRG6O3JQ-00003',
#   'id00109-7tWkRG6O3JQ-00004',
#   'id00109-IfR_OiOg8pE-00005',
#   'id00109-IfR_OiOg8pE-00006',
#   'id00109-QP-PaJYGpok-00007',
#   'id00109-QP-PaJYGpok-00008',
#   'id00109-QP-PaJYGpok-00009',
#   'id00109-QP-PaJYGpok-00010',
#   'id00109-QP-PaJYGpok-00011',
#   'id00109-V9tOjwcKoz8-00012',
#   'id00109-V9tOjwcKoz8-00013',
#   'id00109-V9tOjwcKoz8-00014',
#   'id00109-V9tOjwcKoz8-00015',
#   'id00109-V9tOjwcKoz8-00016',
#   'id00109-V9tOjwcKoz8-00017',
#   'id00109-_JvTuyKEwNg-00018',
#   'id00109-_JvTuyKEwNg-00019',
#   'id00109-_xaJtD5iqTA-00020'],
#  'n000111': ['id00111-0LvdSRPc4uc-00001',
#   'id00111-0LvdSRPc4uc-00002',
#   'id00111-0LvdSRPc4uc-00003',
#   'id00111-0LvdSRPc4uc-00004',
#   'id00111-0LvdSRPc4uc-00005',
#   'id00111-0LvdSRPc4uc-00006',
#   'id00111-0LvdSRPc4uc-00007',
#   'id00111-0LvdSRPc4uc-00008',
#   'id00111-1PH5uN7zpR0-00009',
#   'id00111-1PH5uN7zpR0-00010',
#   'id00111-1PH5uN7zpR0-00011',
#   'id00111-1PH5uN7zpR0-00012',
#   'id00111-1PH5uN7zpR0-00013',
#   'id00111-1PH5uN7zpR0-00014',
#   'id00111-1PH5uN7zpR0-00015',
#   'id00111-2GbTrC0cA4s-00016',
#   'id00111-2GbTrC0cA4s-00017',
#   'id00111-2GbTrC0cA4s-00018',
#   'id00111-2GbTrC0cA4s-00019',
#   'id00111-2GbTrC0cA4s-00020'],
#  'n000114': ['id00114-4Z6jbklO1MQ-00001',
#   'id00114-76RpZmoKAdU-00002',
#   'id00114-76RpZmoKAdU-00003',
#   'id00114-BnbTHkYs80Q-00004',
#   'id00114-BnbTHkYs80Q-00005',
#   'id00114-GG_YfNfJ6Zc-00006',
#   'id00114-GG_YfNfJ6Zc-00007',
#   'id00114-GG_YfNfJ6Zc-00008',
#   'id00114-GG_YfNfJ6Zc-00009',
#   'id00114-GG_YfNfJ6Zc-00010',
#   'id00114-IzKWDScgPO8-00011',
#   'id00114-VXfwKTjEmhM-00012',
#   'id00114-VXfwKTjEmhM-00013',
#   'id00114-VXfwKTjEmhM-00014',
#   'id00114-VXfwKTjEmhM-00015',
#   'id00114-VXfwKTjEmhM-00016',
#   'id00114-f0FdD5_F2j4-00017',
#   'id00114-f0FdD5_F2j4-00018',
#   'id00114-ghtxoTzUUpg-00019',
#   'id00114-ghtxoTzUUpg-00020'],
#  'n000116': ['id00116-9pGUXstaf1Q-00001',
#   'id00116-9pGUXstaf1Q-00002',
#   'id00116-9pGUXstaf1Q-00003',
#   'id00116-9pGUXstaf1Q-00004',
#   'id00116-9pGUXstaf1Q-00005',
#   'id00116-9pGUXstaf1Q-00006',
#   'id00116-9pGUXstaf1Q-00007',
#   'id00116-9pGUXstaf1Q-00008',
#   'id00116-9pGUXstaf1Q-00009',
#   'id00116-Ih4I2H4atXA-00010',
#   'id00116-Ih4I2H4atXA-00011',
#   'id00116-KJh8cDhEf1I-00012',
#   'id00116-M7b-3w3g2ss-00013',
#   'id00116-M7b-3w3g2ss-00014',
#   'id00116-M7b-3w3g2ss-00015',
#   'id00116-M7b-3w3g2ss-00016',
#   'id00116-N9Ll-O0EUYs-00017',
#   'id00116-OJ5KVsgeWSM-00018',
#   'id00116-OJ5KVsgeWSM-00019',
#   'id00116-UmkgH-xbnbY-00020'],
#  'n000117': ['id00117-630xeVpsLhQ-00001',
#   'id00117-RDWOTT1h7KE-00002',
#   'id00117-SZgGycgkED8-00003',
#   'id00117-V9bGQnAMfbs-00004',
#   'id00117-V9bGQnAMfbs-00005',
#   'id00117-V9bGQnAMfbs-00006',
#   'id00117-V9bGQnAMfbs-00007',
#   'id00117-WJKcdm7Dtkc-00008',
#   'id00117-dGCwqu0xGUQ-00009',
#   'id00117-dGCwqu0xGUQ-00010',
#   'id00117-dGCwqu0xGUQ-00011',
#   'id00117-dGCwqu0xGUQ-00012',
#   'id00117-dGCwqu0xGUQ-00013',
#   'id00117-dGCwqu0xGUQ-00014',
#   'id00117-dGCwqu0xGUQ-00015',
#   'id00117-dGCwqu0xGUQ-00016',
#   'id00117-dGCwqu0xGUQ-00017',
#   'id00117-dGCwqu0xGUQ-00018',
#   'id00117-dGCwqu0xGUQ-00019',
#   'id00117-dGCwqu0xGUQ-00020'],
#  'n000126': ['id00126-7YRxEW_DWN8-00001',
#   'id00126-8E-fWWCROk4-00002',
#   'id00126-8E-fWWCROk4-00003',
#   'id00126-8E-fWWCROk4-00004',
#   'id00126-8E-fWWCROk4-00005',
#   'id00126-8E-fWWCROk4-00006',
#   'id00126-8E-fWWCROk4-00007',
#   'id00126-8E-fWWCROk4-00008',
#   'id00126-8E-fWWCROk4-00009',
#   'id00126-8E-fWWCROk4-00010',
#   'id00126-8E-fWWCROk4-00011',
#   'id00126-8E-fWWCROk4-00012',
#   'id00126-8E-fWWCROk4-00013',
#   'id00126-8E-fWWCROk4-00014',
#   'id00126-8E-fWWCROk4-00015',
#   'id00126-8E-fWWCROk4-00016',
#   'id00126-8E-fWWCROk4-00017',
#   'id00126-8E-fWWCROk4-00018',
#   'id00126-8E-fWWCROk4-00019',
# ...
#   'id01423-AU-LI7_wAi8-00015',
#   'id01423-AU-LI7_wAi8-00016',
#   'id01423-AU-LI7_wAi8-00017',
#   'id01423-AU-LI7_wAi8-00018',
#   'id01423-JJCZe_J9Ono-00019',
#   'id01423-JJCZe_J9Ono-00020'],
#  'n001423': ['id01424-3r0KfbBVmI4-00001',
#   'id01424-3r0KfbBVmI4-00002',
#   'id01424-3r0KfbBVmI4-00003',
#   'id01424-3r0KfbBVmI4-00004',
#   'id01424-3r0KfbBVmI4-00005',
#   'id01424-3r0KfbBVmI4-00006',
#   'id01424-3r0KfbBVmI4-00007',
#   'id01424-3r0KfbBVmI4-00008',
#   'id01424-3r0KfbBVmI4-00009',
#   'id01424-3r0KfbBVmI4-00010',
#   'id01424-3r0KfbBVmI4-00011',
#   'id01424-7jk8Ga_1HYU-00012',
#   'id01424-7jk8Ga_1HYU-00013',
#   'id01424-7jk8Ga_1HYU-00014',
#   'id01424-7jk8Ga_1HYU-00015',
#   'id01424-7jk8Ga_1HYU-00016',
#   'id01424-7jk8Ga_1HYU-00017',
#   'id01424-KXP4AbEnk5c-00018',
#   'id01424-MznDnYdH64w-00019',
#   'id01424-MznDnYdH64w-00020'],
#  'n001424': ['id01425-01kS3vxB6kc-00001',
#   'id01425-01kS3vxB6kc-00002',
#   'id01425-01kS3vxB6kc-00003',
#   'id01425-01kS3vxB6kc-00004',
#   'id01425-01kS3vxB6kc-00005',
#   'id01425-01kS3vxB6kc-00006',
#   'id01425-01kS3vxB6kc-00007',
#   'id01425-01kS3vxB6kc-00008',
#   'id01425-01kS3vxB6kc-00009',
#   'id01425-01kS3vxB6kc-00010',
#   'id01425-01kS3vxB6kc-00011',
#   'id01425-01kS3vxB6kc-00012',
#   'id01425-01kS3vxB6kc-00013',
#   'id01425-01kS3vxB6kc-00014',
#   'id01425-01kS3vxB6kc-00015',
#   'id01425-01kS3vxB6kc-00016',
#   'id01425-01kS3vxB6kc-00017',
#   'id01425-01kS3vxB6kc-00018',
#   'id01425-01kS3vxB6kc-00019',
#   'id01425-442rRVRIAcs-00020'],
#  'n001425': ['id01426-4BitxSmMFHc-00001',
#   'id01426-4BitxSmMFHc-00002',
#   'id01426-4BitxSmMFHc-00003',
#   'id01426-4BitxSmMFHc-00004',
#   'id01426-4BitxSmMFHc-00005',
#   'id01426-4BitxSmMFHc-00006',
#   'id01426-4BitxSmMFHc-00007',
#   'id01426-4BitxSmMFHc-00008',
#   'id01426-4BitxSmMFHc-00009',
#   'id01426-4BitxSmMFHc-00010',
#   'id01426-BIhMceKZ_To-00011',
#   'id01426-BIhMceKZ_To-00012',
#   'id01426-BIhMceKZ_To-00013',
#   'id01426-BIhMceKZ_To-00014',
#   'id01426-BIhMceKZ_To-00015',
#   'id01426-BIhMceKZ_To-00016',
#   'id01426-BIhMceKZ_To-00017',
#   'id01426-BIhMceKZ_To-00018',
#   'id01426-HzFd0kZH1Go-00019',
#   'id01426-HzFd0kZH1Go-00020'],
#  'n001429': ['id01429-4xts4goUl0w-00001',
#   'id01429-4xts4goUl0w-00002',
#   'id01429-4xts4goUl0w-00003',
#   'id01429-4xts4goUl0w-00004',
#   'id01429-4xts4goUl0w-00005',
#   'id01429-4xts4goUl0w-00006',
#   'id01429-7AM9HMHnC4U-00007',
#   'id01429-7AM9HMHnC4U-00008',
#   'id01429-7AM9HMHnC4U-00009',
#   'id01429-7AM9HMHnC4U-00010',
#   'id01429-7AM9HMHnC4U-00011',
#   'id01429-7AM9HMHnC4U-00012',
#   'id01429-7AM9HMHnC4U-00013',
#   'id01429-7AM9HMHnC4U-00014',
#   'id01429-7AM9HMHnC4U-00015',
#   'id01429-7AM9HMHnC4U-00016',
#   'id01429-7AM9HMHnC4U-00017',
#   'id01429-7AM9HMHnC4U-00018',
#   'id01429-7AM9HMHnC4U-00019',
#   'id01429-7AM9HMHnC4U-00020'],
#  'n001430': ['id01430-92IFFW_ocl4-00001',
#   'id01430-92IFFW_ocl4-00002',
#   'id01430-HnLJrLkdFAY-00003',
#   'id01430-HnLJrLkdFAY-00004',
#   'id01430-Hy_Qe6DBU58-00005',
#   'id01430-Hy_Qe6DBU58-00006',
#   'id01430-Hy_Qe6DBU58-00007',
#   'id01430-Hy_Qe6DBU58-00008',
#   'id01430-Hy_Qe6DBU58-00009',
#   'id01430-PB21oZ70L-k-00010',
#   'id01430-PB21oZ70L-k-00011',
#   'id01430-PB21oZ70L-k-00012',
#   'id01430-QFH70Vbt3KM-00013',
#   'id01430-QFH70Vbt3KM-00014',
#   'id01430-QFHYJCuYQg4-00015',
#   'id01430-SeVCMWw7E5A-00016',
#   'id01430-SeVCMWw7E5A-00017',
#   'id01430-SeVCMWw7E5A-00018',
#   'id01430-V2-VraPcC3A-00019',
#   'id01430-V2-VraPcC3A-00020'],
#  'n001434': ['id01431-0ykymN9f2Lw-00001',
#   'id01431-0ykymN9f2Lw-00002',
#   'id01431-0ykymN9f2Lw-00003',
#   'id01431-3xQuCFajiV4-00004',
#   'id01431-3xQuCFajiV4-00005',
#   'id01431-3xQuCFajiV4-00006',
#   'id01431-3xQuCFajiV4-00007',
#   'id01431-3xQuCFajiV4-00008',
#   'id01431-3xQuCFajiV4-00009',
#   'id01431-5c7kJoF9ivw-00010',
#   'id01431-5c7kJoF9ivw-00011',
#   'id01431-5c7kJoF9ivw-00012',
#   'id01431-5c7kJoF9ivw-00013',
#   'id01431-5c7kJoF9ivw-00014',
#   'id01431-5c7kJoF9ivw-00015',
#   'id01431-5c7kJoF9ivw-00016',
#   'id01431-6HmbGFHhfRA-00017',
#   'id01431-6HmbGFHhfRA-00018',
#   'id01431-6HmbGFHhfRA-00019',
#   'id01431-6HmbGFHhfRA-00020'],
#  'n001431': ['id01432-5fSvUMZ-v2Q-00001',
#   'id01432-5fSvUMZ-v2Q-00002',
#   'id01432-5fSvUMZ-v2Q-00003',
#   'id01432-AFzRyz7S6rA-00004',
#   'id01432-GAgIFcz-qBU-00005',
#   'id01432-GAgIFcz-qBU-00006',
#   'id01432-GAgIFcz-qBU-00007',
#   'id01432-GAgIFcz-qBU-00008',
#   'id01432-GAgIFcz-qBU-00009',
#   'id01432-GAgIFcz-qBU-00010',
#   'id01432-GAgIFcz-qBU-00011',
#   'id01432-GAgIFcz-qBU-00012',
#   'id01432-GAgIFcz-qBU-00013',
#   'id01432-GAgIFcz-qBU-00014',
#   'id01432-GZ7a-Q18QrA-00015',
#   'id01432-IdVH07LD5TM-00016',
#   'id01432-IdVH07LD5TM-00017',
#   'id01432-IdVH07LD5TM-00018',
#   'id01432-IdVH07LD5TM-00019',
#   'id01432-IdVH07LD5TM-00020'],
#  'n001432': ['id01433-1H_7zuBbTdU-00001',
#   'id01433-1H_7zuBbTdU-00002',
#   'id01433-1H_7zuBbTdU-00003',
#   'id01433-1H_7zuBbTdU-00004',
#   'id01433-1H_7zuBbTdU-00005',
#   'id01433-1H_7zuBbTdU-00006',
#   'id01433-1H_7zuBbTdU-00007',
#   'id01433-1H_7zuBbTdU-00008',
#   'id01433-1lrlvYRFKZA-00009',
#   'id01433-1lrlvYRFKZA-00010',
#   'id01433-1lrlvYRFKZA-00011',
#   'id01433-1lrlvYRFKZA-00012',
#   'id01433-1lrlvYRFKZA-00013',
#   'id01433-1lrlvYRFKZA-00014',
#   'id01433-1lrlvYRFKZA-00015',
#   'id01433-1lrlvYRFKZA-00016',
#   'id01433-1lrlvYRFKZA-00017',
#   'id01433-2RvcaflrnNM-00018',
#   'id01433-2RvcaflrnNM-00019',
#   'id01433-2RvcaflrnNM-00020'],
#  'n001433': ['id01434-42C3rtkG2ZI-00001',
#   'id01434-42C3rtkG2ZI-00002',
#   'id01434-6rhc4BSS7lI-00003',
#   'id01434-6rhc4BSS7lI-00004',
#   'id01434-6rhc4BSS7lI-00005',
#   'id01434-6rhc4BSS7lI-00006',
#   'id01434-6rhc4BSS7lI-00007',
#   'id01434-6rhc4BSS7lI-00008',
#   'id01434-6rhc4BSS7lI-00009',
#   'id01434-6rhc4BSS7lI-00010',
#   'id01434-6rhc4BSS7lI-00011',
#   'id01434-6rhc4BSS7lI-00012',
#   'id01434-6rhc4BSS7lI-00013',
#   'id01434-6rhc4BSS7lI-00014',
#   'id01434-6rhc4BSS7lI-00015',
#   'id01434-6rhc4BSS7lI-00016',
#   'id01434-6rhc4BSS7lI-00017',
#   'id01434-6rhc4BSS7lI-00018',
#   'id01434-9N69i-TKuHU-00019',
#   'id01434-9N69i-TKuHU-00020'],
#  'n001436': ['id01436-2xli9X5bkPc-00001',
#   'id01436-58vvf9TDJ-w-00002',
#   'id01436-58vvf9TDJ-w-00003',
#   'id01436-58vvf9TDJ-w-00004',
#   'id01436-58vvf9TDJ-w-00005',
#   'id01436-58vvf9TDJ-w-00006',
#   'id01436-58vvf9TDJ-w-00007',
#   'id01436-58vvf9TDJ-w-00008',
#   'id01436-GpXXVj1-u6A-00009',
#   'id01436-H1nsaOHNqXY-00010',
#   'id01436-H1nsaOHNqXY-00011',
#   'id01436-H1nsaOHNqXY-00012',
#   'id01436-H1nsaOHNqXY-00013',
#   'id01436-H1nsaOHNqXY-00014',
#   'id01436-H1nsaOHNqXY-00015',
#   'id01436-H1nsaOHNqXY-00016',
#   'id01436-MK7U1QXgI_s-00017',
#   'id01436-MK7U1QXgI_s-00018',
#   'id01436-MK7U1QXgI_s-00019',
#   'id01436-MK7U1QXgI_s-00020'],
#  'n001438': ['id01438-3w_8VkCNVCM-00001',
#   'id01438-3w_8VkCNVCM-00002',
#   'id01438-3w_8VkCNVCM-00003',
#   'id01438-BuQzmPKhhDY-00004',
#   'id01438-BuQzmPKhhDY-00005',
#   'id01438-BuQzmPKhhDY-00006',
#   'id01438-BuQzmPKhhDY-00007',
#   'id01438-BuQzmPKhhDY-00008',
#   'id01438-J8GJm9-WnVw-00009',
#   'id01438-M3Lstte__cc-00010',
#   'id01438-M3Lstte__cc-00011',
#   'id01438-aRiVKT9ZAA4-00012',
#   'id01438-aRiVKT9ZAA4-00013',
#   'id01438-aRiVKT9ZAA4-00014',
#   'id01438-aRiVKT9ZAA4-00015',
#   'id01438-aRiVKT9ZAA4-00016',
#   'id01438-aRiVKT9ZAA4-00017',
#   'id01438-aRiVKT9ZAA4-00018',
#   'id01438-aRiVKT9ZAA4-00019',
#   'id01438-aRiVKT9ZAA4-00020'],
#  'n001439': ['id01439-480ybIiwVHE-00001',
#   'id01439-480ybIiwVHE-00002',
#   'id01439-480ybIiwVHE-00003',
#   'id01439-480ybIiwVHE-00004',
#   'id01439-480ybIiwVHE-00005',
#   'id01439-480ybIiwVHE-00006',
#   'id01439-480ybIiwVHE-00007',
#   'id01439-480ybIiwVHE-00008',
#   'id01439-480ybIiwVHE-00009',
#   'id01439-480ybIiwVHE-00010',
#   'id01439-480ybIiwVHE-00011',
#   'id01439-480ybIiwVHE-00012',
#   'id01439-480ybIiwVHE-00013',
#   'id01439-480ybIiwVHE-00014',
#   'id01439-480ybIiwVHE-00015',
#   'id01439-480ybIiwVHE-00016',
#   'id01439-480ybIiwVHE-00017',
#   'id01439-480ybIiwVHE-00018',
#   'id01439-7bI3x96EtCY-00019',
#   'id01439-7bI3x96EtCY-00020'],
#  'n001445': ['id01445-6a2G4jXRN0s-00001',
#   'id01445-6a2G4jXRN0s-00002',
#   'id01445-HAESZFjhRIY-00003',
#   'id01445-HDMKp5u0IXY-00004',
#   'id01445-IdkW2nx95VI-00005',
#   'id01445-J83TSVxrbpY-00006',
#   'id01445-J83TSVxrbpY-00007',
#   'id01445-J83TSVxrbpY-00008',
#   'id01445-Lf_zi3v0KZw-00009',
#   'id01445-Lf_zi3v0KZw-00010',
#   'id01445-Lf_zi3v0KZw-00011',
#   'id01445-Wb4EmKZel9U-00012',
#   'id01445-Wb4EmKZel9U-00013',
#   'id01445-Wb4EmKZel9U-00014',
#   'id01445-Wb4EmKZel9U-00015',
#   'id01445-Wb4EmKZel9U-00016',
#   'id01445-Wb4EmKZel9U-00017',
#   'id01445-Wb4EmKZel9U-00018',
#   'id01445-Wb4EmKZel9U-00019',
#   'id01445-Y_ckAJWeoaI-00020'],
#  'n001447': ['id01447-2V4l2OzfhAw-00001',
#   'id01447-2V4l2OzfhAw-00002',
#   'id01447-2V4l2OzfhAw-00003',
#   'id01447-2V4l2OzfhAw-00004',
#   'id01447-2V4l2OzfhAw-00005',
#   'id01447-2V4l2OzfhAw-00006',
#   'id01447-2V4l2OzfhAw-00007',
#   'id01447-2V4l2OzfhAw-00008',
#   'id01447-2V4l2OzfhAw-00009',
#   'id01447-2V4l2OzfhAw-00010',
#   'id01447-3SSMPNucKZQ-00011',
#   'id01447-3SSMPNucKZQ-00012',
#   'id01447-3SSMPNucKZQ-00013',
#   'id01447-3SSMPNucKZQ-00014',
#   'id01447-3SSMPNucKZQ-00015',
#   'id01447-Go5dDru-Woo-00016',
#   'id01447-Go5dDru-Woo-00017',
#   'id01447-H852cIp74Kw-00018',
#   'id01447-H852cIp74Kw-00019',
#   'id01447-H852cIp74Kw-00020'],
#  'n001448': ['id01448-16n4Ypylo4E-00001',
#   'id01448-16n4Ypylo4E-00002',
#   'id01448-16n4Ypylo4E-00003',
#   'id01448-16n4Ypylo4E-00004',
#   'id01448-16n4Ypylo4E-00005',
#   'id01448-16n4Ypylo4E-00006',
#   'id01448-2tSJ-8KjpJ0-00007',
#   'id01448-2tSJ-8KjpJ0-00008',
#   'id01448-2tSJ-8KjpJ0-00009',
#   'id01448-2tSJ-8KjpJ0-00010',
#   'id01448-2tSJ-8KjpJ0-00011',
#   'id01448-6LIz0pvQ4Ls-00012',
#   'id01448-6LIz0pvQ4Ls-00013',
#   'id01448-6LIz0pvQ4Ls-00014',
#   'id01448-6LIz0pvQ4Ls-00015',
#   'id01448-6LIz0pvQ4Ls-00016',
#   'id01448-6LIz0pvQ4Ls-00017',
#   'id01448-6LIz0pvQ4Ls-00018',
#   'id01448-6hjb1fRmYl4-00019',
#   'id01448-6hjb1fRmYl4-00020'],
#  'n001449': ['id01449-37qqdKriGpE-00001',
#   'id01449-37qqdKriGpE-00002',
#   'id01449-4eNCbt8Uh_k-00003',
#   'id01449-4eNCbt8Uh_k-00004',
#   'id01449-4eNCbt8Uh_k-00005',
#   'id01449-4eNCbt8Uh_k-00006',
#   'id01449-4eNCbt8Uh_k-00007',
#   'id01449-4eNCbt8Uh_k-00008',
#   'id01449-4eNCbt8Uh_k-00009',
#   'id01449-4eNCbt8Uh_k-00010',
#   'id01449-4eNCbt8Uh_k-00011',
#   'id01449-4eNCbt8Uh_k-00012',
#   'id01449-4eNCbt8Uh_k-00013',
#   'id01449-4eNCbt8Uh_k-00014',
#   'id01449-4eNCbt8Uh_k-00015',
#   'id01449-4eNCbt8Uh_k-00016',
#   'id01449-4eNCbt8Uh_k-00017',
#   'id01449-4eNCbt8Uh_k-00018',
#   'id01449-4eNCbt8Uh_k-00019',
#   'id01449-4eNCbt8Uh_k-00020'],
#  'n001450': ['id01450-1zAGmETaG24-00001',
#   'id01450-1zAGmETaG24-00002',
#   'id01450-1zAGmETaG24-00003',
#   'id01450-1zAGmETaG24-00004',
#   'id01450-1zAGmETaG24-00005',
#   'id01450-1zAGmETaG24-00006',
#   'id01450-1zAGmETaG24-00007',
#   'id01450-1zAGmETaG24-00008',
#   'id01450-1zAGmETaG24-00009',
#   'id01450-1zAGmETaG24-00010',
#   'id01450-1zAGmETaG24-00011',
#   'id01450-1zAGmETaG24-00012',
#   'id01450-1zAGmETaG24-00013',
#   'id01450-1zAGmETaG24-00014',
#   'id01450-1zAGmETaG24-00015',
#   'id01450-1zAGmETaG24-00016',
#   'id01450-5Wb_vaf4_7U-00017',
#   'id01450-5Wb_vaf4_7U-00018',
#   'id01450-5Wb_vaf4_7U-00019',
#   'id01450-5Wb_vaf4_7U-00020'],
#  'n001451': ['id01451-0MaVwwg9IVw-00001',
#   'id01451-0MaVwwg9IVw-00002',
#   'id01451-0sl6HgM4sZc-00003',
#   'id01451-0sl6HgM4sZc-00004',
#   'id01451-0sl6HgM4sZc-00005',
#   'id01451-0sl6HgM4sZc-00006',
#   'id01451-0sl6HgM4sZc-00007',
#   'id01451-0sl6HgM4sZc-00008',
#   'id01451-0sl6HgM4sZc-00009',
#   'id01451-6lbtKnNOAgo-00010',
#   'id01451-82CtcmBgMLY-00011',
#   'id01451-82CtcmBgMLY-00012',
#   'id01451-82CtcmBgMLY-00013',
#   'id01451-82CtcmBgMLY-00014',
#   'id01451-82CtcmBgMLY-00015',
#   'id01451-82CtcmBgMLY-00016',
#   'id01451-82CtcmBgMLY-00017',
#   'id01451-82CtcmBgMLY-00018',
#   'id01451-82CtcmBgMLY-00019',
#   'id01451-82CtcmBgMLY-00020'],
#  'n001452': ['id01452-4MqeoSxSy3w-00001',
#   'id01452-PYNtKMPCWTM-00002',
#   'id01452-PYNtKMPCWTM-00003',
#   'id01452-PYNtKMPCWTM-00004',
#   'id01452-RiNzx46r_FE-00005',
#   'id01452-RiNzx46r_FE-00006',
#   'id01452-RiNzx46r_FE-00007',
#   'id01452-RiNzx46r_FE-00008',
#   'id01452-RiNzx46r_FE-00009',
#   'id01452-RiNzx46r_FE-00010',
#   'id01452-RiNzx46r_FE-00011',
#   'id01452-RiNzx46r_FE-00012',
#   'id01452-RiNzx46r_FE-00013',
#   'id01452-RiNzx46r_FE-00014',
#   'id01452-RiNzx46r_FE-00015',
#   'id01452-RiNzx46r_FE-00016',
#   'id01452-Yvf1_-n6DGc-00017',
#   'id01452-Yvf1_-n6DGc-00018',
#   'id01452-Yvf1_-n6DGc-00019',
#   'id01452-Yvf1_-n6DGc-00020'],
#  'n001455': ['id01455-5Y6U3Wh_zZI-00001',
#   'id01455-5Y6U3Wh_zZI-00002',
#   'id01455-5Y6U3Wh_zZI-00003',
#   'id01455-9MSYEz2SV1I-00004',
#   'id01455-9MSYEz2SV1I-00005',
#   'id01455-Ae_P5BtKj_Q-00006',
#   'id01455-Ep6qqup_Umw-00007',
#   'id01455-Ep6qqup_Umw-00008',
#   'id01455-FvW8-PVetLw-00009',
#   'id01455-OUWOrhwNs1Y-00010',
#   'id01455-PG_Lld6ONfI-00011',
#   'id01455-VhSBcIEiVWw-00012',
#   'id01455-VhSBcIEiVWw-00013',
#   'id01455-VhSBcIEiVWw-00014',
#   'id01455-VhSBcIEiVWw-00015',
#   'id01455-VhSBcIEiVWw-00016',
#   'id01455-VhSBcIEiVWw-00017',
#   'id01455-VhSBcIEiVWw-00018',
#   'id01455-VhSBcIEiVWw-00019',
#   'id01455-VhSBcIEiVWw-00020'],
#  'n001456': ['id01456-8UMvDUGtXxU-00001',
#   'id01456-8UMvDUGtXxU-00002',
#   'id01456-8UMvDUGtXxU-00003',
#   'id01456-8UMvDUGtXxU-00004',
#   'id01456-EHKVKaVR__U-00005',
#   'id01456-EHKVKaVR__U-00006',
#   'id01456-EHKVKaVR__U-00007',
#   'id01456-JGw4ixy5rGk-00008',
#   'id01456-JGw4ixy5rGk-00009',
#   'id01456-JGw4ixy5rGk-00010',
#   'id01456-JGw4ixy5rGk-00011',
#   'id01456-JGw4ixy5rGk-00012',
#   'id01456-JGw4ixy5rGk-00013',
#   'id01456-JGw4ixy5rGk-00014',
#   'id01456-JGw4ixy5rGk-00015',
#   'id01456-JGw4ixy5rGk-00016',
#   'id01456-JleFvdC-X7g-00017',
#   'id01456-Uu3BeIXhz-M-00018',
#   'id01456-Uu3BeIXhz-M-00019',
#   'id01456-cpXObj6vEVU-00020'],
#  'n001457': ['id01457-53E3X_srRAI-00001',
#   'id01457-53E3X_srRAI-00002',
#   'id01457-53E3X_srRAI-00003',
#   'id01457-53E3X_srRAI-00004',
#   'id01457-53E3X_srRAI-00005',
#   'id01457-53E3X_srRAI-00006',
#   'id01457-53E3X_srRAI-00007',
#   'id01457-53E3X_srRAI-00008',
#   'id01457-53E3X_srRAI-00009',
#   'id01457-8JXG7OC8Vss-00010',
#   'id01457-8JXG7OC8Vss-00011',
#   'id01457-8JXG7OC8Vss-00012',
#   'id01457-8JXG7OC8Vss-00013',
#   'id01457-8JXG7OC8Vss-00014',
#   'id01457-8JXG7OC8Vss-00015',
#   'id01457-8JXG7OC8Vss-00016',
#   'id01457-8JXG7OC8Vss-00017',
#   'id01457-8JXG7OC8Vss-00018',
#   'id01457-8JXG7OC8Vss-00019',
#   'id01457-8JXG7OC8Vss-00020'],
#  'n001466': ['id01458-45RqUmxDXiY-00001',
#   'id01458-45RqUmxDXiY-00002',
#   'id01458-45RqUmxDXiY-00003',
#   'id01458-5WZdFPkLhQM-00004',
#   'id01458-8RcNw8TNepE-00005',
#   'id01458-HSfRQbGLST0-00006',
#   'id01458-HSfRQbGLST0-00007',
#   'id01458-HSfRQbGLST0-00008',
#   'id01458-HSfRQbGLST0-00009',
#   'id01458-HSfRQbGLST0-00010',
#   'id01458-HSfRQbGLST0-00011',
#   'id01458-HSfRQbGLST0-00012',
#   'id01458-HSfRQbGLST0-00013',
#   'id01458-HSfRQbGLST0-00014',
#   'id01458-HSfRQbGLST0-00015',
#   'id01458-HSfRQbGLST0-00016',
#   'id01458-HSfRQbGLST0-00017',
#   'id01458-HSfRQbGLST0-00018',
#   'id01458-HSfRQbGLST0-00019',
#   'id01458-HSfRQbGLST0-00020'],
#  'n001458': ['id01459-13TMZrwf6z0-00001',
#   'id01459-13TMZrwf6z0-00002',
#   'id01459-3iKbQujWsGk-00003',
#   'id01459-3iKbQujWsGk-00004',
#   'id01459-3iKbQujWsGk-00005',
#   'id01459-3iKbQujWsGk-00006',
#   'id01459-5ButvtAvhRg-00007',
#   'id01459-5OGwo1oWonc-00008',
#   'id01459-5OGwo1oWonc-00009',
#   'id01459-5OGwo1oWonc-00010',
#   'id01459-5OGwo1oWonc-00011',
#   'id01459-5OGwo1oWonc-00012',
#   'id01459-5OGwo1oWonc-00013',
#   'id01459-5OGwo1oWonc-00014',
#   'id01459-96008O4qIBQ-00015',
#   'id01459-96008O4qIBQ-00016',
#   'id01459-96008O4qIBQ-00017',
#   'id01459-96008O4qIBQ-00018',
#   'id01459-96008O4qIBQ-00019',
#   'id01459-96008O4qIBQ-00020'],
#  'n001460': ['id01461-0TOhqIyQCI0-00001',
#   'id01461-0TOhqIyQCI0-00002',
#   'id01461-EQI36RtElfA-00003',
#   'id01461-EQI36RtElfA-00004',
#   'id01461-EoEapzyTnuM-00005',
#   'id01461-EoEapzyTnuM-00006',
#   'id01461-EoEapzyTnuM-00007',
#   'id01461-GXhJp2BpwxA-00008',
#   'id01461-GXhJp2BpwxA-00009',
#   'id01461-GXhJp2BpwxA-00010',
#   'id01461-GXhJp2BpwxA-00011',
#   'id01461-GbpCKIcUyGA-00012',
#   'id01461-GbpCKIcUyGA-00013',
#   'id01461-HRUcEvDL6uw-00014',
#   'id01461-IbXfrZt-6pw-00015',
#   'id01461-LuLC17MIE5k-00016',
#   'id01461-LuLC17MIE5k-00017',
#   'id01461-LuLC17MIE5k-00018',
#   'id01461-LuLC17MIE5k-00019',
#   'id01461-LuLC17MIE5k-00020'],
#  ...}

# %%
full_data =[]
for i in list(train_xvec.keys()):
    full_data.append(train_xvec[i])
full_data = np.array(full_data)

# %%
full_data.shape
# Out:
# (1092009, 512)

# %%
spk_uttids = load_json('../../../data/spk_utt_ids.json')
face_map = load_json('../../../data/face_map.json')
face_ids = [value for value in list(spk_uttids.keys()) if value in list(face_map.keys())]
face_maps_dict = {e:i for e,i in enumerate(face_ids)}

full_tuples = []
for i,v in enumerate(face_ids[:200]):
    mixed = itertools.product(spk_uttids[v],face_map[v])
    tuple_set = [(x[0],x[1],i) for x in mixed]
    full_tuples.extend(tuple_set)
write_to_json(full_tuples,'../../../data/200spk_tuples.json')

# %%
len(face_ids)
# Out:
# 5734

# %%
len(full_tuples)
# Out:
# 400000

# %%
new_data ={}
for e,i in enumerate(list(train_xvec.keys())):
    new_data[i] = data[e]

# %%
test_xvec = { key.strip():vec.tolist() for key,vec in read_vec_flt_ark('../../../data/xvec_v2_test.ark')}
assert(len(list(test_xvec.keys()))==36237)
test_spk2utt = {line.strip().split(' ')[0]:line.strip().split(' ')[1:] for line in open('../../../data/spk2utt_test','r').readlines()}
assert(len(list(test_spk2utt.keys()))==118)

# %%
test_data = []
for i in list(test_xvec.keys()):
    test_data.append(test_xvec[i])
test_data = np.array(test_data)
new_test = -1 +(2*(test_data - mn)) / (mx-mn)

# %%
total_data = np.concatenate((full_data,test_data),axis=0)
mx = np.max(total_data,axis=0)
mn = np.min(total_data,axis=0)
data = -1 +(2*(full_data - mn)) / (mx-mn)
new_test = -1 +(2*(test_data - mn)) / (mx-mn)

# %%
write_to_json(data.tolist(),'../../../data/norm_train_xvecs.json')
#write_to_json(new_test.tolist(),'../../../data/norm_test_xvecs.json')
